# %%
#install packages
# !pip install --quiet pandas numpy scipy scikit-learn plotly seaborn

# %%
#stimulated dataset
import numpy as np
import pandas as pd

# Simulate OTU table (samples × taxa)
n_samples, n_taxa = 50, 20
np.random.seed(42)
otu = np.random.poisson(lam=50, size=(n_samples, n_taxa))
otu = pd.DataFrame(otu, columns=[f"Taxon_{i+1}" for i in range(n_taxa)])
otu.index = [f"S{i+1}" for i in range(n_samples)]

# Metadata (BMI, age, sex, obesity group)
meta = pd.DataFrame({
    "BMI": np.round(np.random.normal(27, 5, n_samples), 1),
    "age": np.random.randint(18, 70, n_samples),
    "sex": np.random.choice(["M", "F"], n_samples)
}, index=otu.index)
meta["obesity"] = pd.cut(meta["BMI"], bins=[0,25,30,100], labels=["normal","overweight","obese"])

otu.head(), meta.head()
# Out:
# (    Taxon_1  Taxon_2  Taxon_3  Taxon_4  Taxon_5  Taxon_6  Taxon_7  Taxon_8  \
#  S1       47       55       42       52       58       43       46       49
#  S2       64       52       38       33       48       58       45       41
#  S3       50       46       61       48       44       45       63       53
#  S4       34       61       41       54       44       47       53       39
#  S5       47       60       53       52       39       51       53       55
#
#      Taxon_9  Taxon_10  Taxon_11  Taxon_12  Taxon_13  Taxon_14  Taxon_15  \
#  S1       52        45        49        43        52        52        46
#  S2       56        54        56        47        59        46        46
#  S3       57        60        46        44        48        40        65
#  S4       46        54        50        53        54        64        47
#  S5       46        53        53        39        45        60        57
#
#      Taxon_16  Taxon_17  Taxon_18  Taxon_19  Taxon_20
#  S1        54        40        45        46        51
#  S2        55        60        40        56        56
#  S3        50        69        50        45        52
#  S4        45        57        51        39        61
#  S5        52        43        45        53        62  ,
#       BMI  age sex     obesity
#  S1  29.7   38   M  overweight
#  S2  27.0   28   M  overweight
#  S3  24.8   56   M      normal
#  S4  26.5   45   M  overweight
#  S5  26.6   22   F  overweight)

# %%
#cleaning the  dataset
# Remove low-depth samples & rare taxa
sample_sums = otu.sum(axis=1)
otu = otu[sample_sums >= 500]   # keep good samples

taxa_sums = otu.sum(axis=0)
otu = otu.loc[:, taxa_sums >= 100]   # keep common taxa
otu.shape
# Out:
# (50, 20)

# %%
#analysis
def shannon(counts):
    p = counts / counts.sum()
    p = p[p > 0]
    return -(p * np.log(p)).sum()

alpha = otu.apply(shannon, axis=1)
alpha = alpha.to_frame("shannon").join(meta)
alpha.head()
# Out:
#      shannon   BMI  age sex     obesity
# S1  2.991051  29.7   38   M  overweight
# S2  2.982462  27.0   28   M  overweight
# S3  2.984521  24.8   56   M      normal
# S4  2.983140  26.5   45   M  overweight
# S5  2.987674  26.6   22   F  overweight

# %%
#pca on transformed data
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

rel_abund = otu.div(otu.sum(axis=1), axis=0)
clr = np.log(rel_abund + 1e-6) - np.log(rel_abund + 1e-6).mean(axis=1).values[:,None]

pca = PCA(n_components=2)
pcs = pca.fit_transform(clr)
pcoa_df = pd.DataFrame(pcs, columns=["PC1","PC2"], index=otu.index).join(meta)

# %%
#visualization
import plotly.express as px

# PCA scatter
fig = px.scatter(pcoa_df, x="PC1", y="PC2", color="obesity", hover_data=["BMI","age","sex"],
                 title="Microbiome PCA (CLR transformed)")
fig.show()

# Alpha diversity boxplot
fig2 = px.box(alpha.reset_index(), x="obesity", y="shannon", points="all",
              title="Shannon Diversity by Obesity Status")
fig2.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="8ed2b91f-9918-4365-885d-029cab39d6b1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8ed2b91f-9918-4365-885d-029cab39d6b1")) {                    Plotly.newPlot(                        "8ed2b91f-9918-4365-885d-029cab39d6b1",                        [{"customdata":[[29.7,38,"M"],[27.0,28,"M"],[26.5,45,"M"],[26.6,22,"F"],[25.1,34,"F"],[25.7,37,"M"],[29.8,63,"F"],[25.5,29,"M"],[25.3,34,"M"],[28.8,36,"M"],[26.5,43,"F"],[29.2,65,"M"],[27.7,49,"F"],[29.5,28,"F"],[26.2,44,"F"],[28.2,68,"F"],[25.6,45,"M"],[29.5,21,"F"],[26.5,62,"M"],[28.3,26,"F"],[29.3,25,"F"],[27.5,62,"F"]],"hovertemplate":"obesity=overweight\u003cbr\u003ePC1=%{x}\u003cbr\u003ePC2=%{y}\u003cbr\u003eBMI=%{customdata[0]}\u003cbr\u003eage=%{customdata[1]}\u003cbr\u003esex=%{customdata[2]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"overweight","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"overweight","orientation":"v","showlegend":true,"x":[-0.1990019050107986,0.023845209892083108,-0.026604225616695565,-0.21255231196473798,0.180495288780696,-0.09270866288176463,0.5014574071430117,0.49733706923764937,0.1492435329099823,-0.42087511547503964,0.15733960497603003,0.11001402050318579,0.07396119423741819,0.19174875266546054,-0.026995429404212335,0.3124449321599215,-0.260013171689452,-0.740875989127241,0.11671249494410614,0.0806480190408642,-0.2702163231229187,0.19529206448427133],"xaxis":"x","y":[0.200959989803138,-0.18673847570876143,-0.07230397033062361,-0.04322246594900117,0.5104237905575433,-0.0669700037829022,0.10558037583421002,0.002336231315952602,0.11941326023418873,-0.08182509900804498,-0.09152830807165223,0.21594985852011978,0.08220535138048128,-0.09958836068844291,0.3661698832041579,0.005796345068026146,0.0445986617453014,0.3160372996327571,0.21008591961867495,-0.3595559127377806,-0.14857615866316667,-0.032024157236532194],"yaxis":"y","type":"scatter"},{"customdata":[[24.8,56,"M"],[19.1,61,"M"],[21.4,61,"M"],[21.0,69,"F"],[18.0,50,"M"],[24.3,41,"M"],[23.1,40,"F"],[23.9,32,"F"],[24.6,28,"F"],[17.1,68,"F"],[21.6,34,"F"],[22.4,44,"M"],[14.3,35,"F"],[20.9,64,"M"],[24.7,24,"M"],[19.5,65,"F"]],"hovertemplate":"obesity=normal\u003cbr\u003ePC1=%{x}\u003cbr\u003ePC2=%{y}\u003cbr\u003eBMI=%{customdata[0]}\u003cbr\u003eage=%{customdata[1]}\u003cbr\u003esex=%{customdata[2]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"normal","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"normal","orientation":"v","showlegend":true,"x":[-0.023734943521300213,-0.20010210529110956,-0.2781152636839239,0.2792228240233374,-0.19605814821236625,-0.11796784958565754,0.16752073435326534,0.22038537147154877,0.17615075911192063,-0.1629351491621923,0.06556073343382396,-0.014058838037714162,-0.1613576387780439,-0.04142006398626112,0.1555945296494676,0.1603486795182941],"xaxis":"x","y":[-0.07686748848287923,0.22893425234291492,-0.20299246353422282,0.19022079520734447,0.1942587774224704,-0.19527036662178532,-0.09737810101848587,-0.1661393395942814,0.23551943039705497,-0.0016073331634156595,0.194840348282187,-0.06776044196671158,-0.17271875778158133,-0.12676821587105733,0.008427051818228812,-0.34034241082810185],"yaxis":"y","type":"scatter"},{"customdata":[[35.0,58,"M"],[30.5,23,"M"],[32.9,68,"M"],[35.7,23,"F"],[38.2,53,"F"],[30.2,55,"M"],[30.7,67,"M"],[37.4,31,"F"],[32.5,68,"F"],[36.8,64,"F"],[40.2,52,"M"],[32.4,69,"M"]],"hovertemplate":"obesity=obese\u003cbr\u003ePC1=%{x}\u003cbr\u003ePC2=%{y}\u003cbr\u003eBMI=%{customdata[0]}\u003cbr\u003eage=%{customdata[1]}\u003cbr\u003esex=%{customdata[2]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"obese","marker":{"color":"#00cc96","symbol":"circle"},"mode":"markers","name":"o ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="0e827cb6-3663-4d4b-a703-88579fdc6776" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0e827cb6-3663-4d4b-a703-88579fdc6776")) {                    Plotly.newPlot(                        "0e827cb6-3663-4d4b-a703-88579fdc6776",                        [{"alignmentgroup":"True","boxpoints":"all","hovertemplate":"obesity=%{x}\u003cbr\u003eshannon=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x":["overweight","overweight","normal","overweight","overweight","overweight","overweight","obese","overweight","overweight","obese","overweight","obese","overweight","overweight","overweight","normal","normal","normal","overweight","obese","obese","obese","overweight","normal","normal","normal","normal","overweight","normal","normal","obese","normal","overweight","obese","normal","normal","overweight","obese","obese","normal","overweight","normal","overweight","obese","normal","overweight","overweight","obese","overweight"],"x0":" ","xaxis":"x","y":[2.9910506832299544,2.982462467774233,2.98452077997278,2.9831399001653587,2.9876735695489156,2.9828312420872996,2.9849035069697694,2.9820325070947034,2.9848166796687003,2.980178722737726,2.984436555262864,2.9859103214283076,2.986068556108465,2.985503624406704,2.988658888549362,2.986694870848508,2.9876382266237647,2.986574809412045,2.9882020135373946,2.9889842226895422,2.97907051127699,2.9841439166599977,2.9848226473936825,2.9888679060605523,2.98623633505492,2.9820045923090284,2.9836397892393283,2.9833363308144247,2.9834064778099436,2.9800888803595615,2.9916312590519856,2.984421462372683,2.9873862046563717,2.986980337857005,2.986143623496327,2.9866301088131033,2.984342563016904,2.985220678421115,2.9857892634477308,2.988100593653332,2.9882529653022667,2.977460702936197,2.9857315021187105,2.9816208544075895,2.990517434586007,2.9877765943715695,2.9850058905722885,2.986137353699331,2.986490902533171,2.990925791460524],"y0":" ","yaxis":"y","type":"box"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type": ...

# %%
#saving resut
otu.to_csv("otu_clean.csv")
meta.to_csv("metadata.csv")
alpha.to_csv("alpha_diversity.csv")
pcoa_df.to_csv("ordination.csv")
